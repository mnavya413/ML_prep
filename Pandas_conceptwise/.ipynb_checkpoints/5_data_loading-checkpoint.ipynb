# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('HR Data.csv')

# %%
df
# Out:
#      Attrition    Business Travel Department          Education  \
# 0          Yes      Travel_Rarely      Sales  Associates Degree
# 1           No  Travel_Frequently        R&D        High School
# 2          Yes      Travel_Rarely        R&D  Associates Degree
# 3           No  Travel_Frequently        R&D    Master's Degree
# 4           No      Travel_Rarely        R&D        High School
# ...        ...                ...        ...                ...
# 1465       Yes         Non-Travel        R&D    Master's Degree
# 1466       Yes  Travel_Frequently        R&D  Associates Degree
# 1467       Yes  Travel_Frequently      Sales    Master's Degree
# 1468       Yes      Travel_Rarely      Sales  Bachelor's Degree
# 1469       Yes      Travel_Rarely        R&D        High School
#
#        Education Field      Emp No  Employee Number  Gender  \
# 0        Life Sciences     STAFF-1                1  Female
# 1        Life Sciences     STAFF-2                2    Male
# ...

# %%
df.size
# Out:
# 51450

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   Department                  1470 non-null   object
#  3   Education                   1470 non-null   object
#  4   Education Field             1470 non-null   object
#  5   Emp No                      1470 non-null   object
#  6   Employee Number             1470 non-null   int64
#  7   Gender                      1470 non-null   object
#  8   Job Role                    1470 non-null   object
#  9   Job Satisfaction            1470 non-null   int64
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
df.describe()
# Out:
#        Employee Number  Job Satisfaction          Age  Distance From Home  \
# count      1470.000000       1470.000000  1470.000000         1470.000000
# mean       1024.865306          2.728571    36.923810            9.192517
# std         602.024335          1.102846     9.135373            8.106864
# min           1.000000          1.000000    18.000000            1.000000
# 25%         491.250000          2.000000    30.000000            2.000000
# 50%        1020.500000          3.000000    36.000000            7.000000
# 75%        1555.750000          4.000000    43.000000           14.000000
# max        2068.000000          4.000000    60.000000           29.000000
#
#        Employee Count  Environment Satisfaction  Hourly Rate  Job Involvement  \
# count          1470.0               1470.000000  1470.000000      1470.000000
# mean              1.0                  2.721769    65.891156         2.729932
# ...

# %%
df.head()
# Out:
#   Attrition    Business Travel Department          Education Education Field  \
# 0       Yes      Travel_Rarely      Sales  Associates Degree   Life Sciences
# 1        No  Travel_Frequently        R&D        High School   Life Sciences
# 2       Yes      Travel_Rarely        R&D  Associates Degree           Other
# 3        No  Travel_Frequently        R&D    Master's Degree   Life Sciences
# 4        No      Travel_Rarely        R&D        High School         Medical
#
#     Emp No  Employee Number  Gender               Job Role  Job Satisfaction  \
# 0  STAFF-1                1  Female        Sales Executive                 4
# 1  STAFF-2                2    Male     Research Scientist                 2
# 2  STAFF-4                4    Male  Laboratory Technician                 3
# 3  STAFF-5                5  Female     Research Scientist                 3
# 4  STAFF-7                7    Male  Laboratory Technician                 2
#
# ...

# %%
df.tail(4)
# Out:
#      Attrition    Business Travel Department          Education  \
# 1466       Yes  Travel_Frequently        R&D  Associates Degree
# 1467       Yes  Travel_Frequently      Sales    Master's Degree
# 1468       Yes      Travel_Rarely      Sales  Bachelor's Degree
# 1469       Yes      Travel_Rarely        R&D        High School
#
#      Education Field      Emp No  Employee Number Gender  \
# 1466   Life Sciences  STAFF-1868             1868   Male
# 1467           Other  STAFF-1667             1667   Male
# 1468   Life Sciences  STAFF-1702             1702   Male
# 1469   Life Sciences  STAFF-1878             1878   Male
#
#                   Job Role  Job Satisfaction  ... Relationship Satisfaction  \
# 1466    Research Scientist                 4  ...                         2
# 1467       Sales Executive                 4  ...                         1
# 1468  Sales Representative                 4  ...                         2
# ...

# %%
df.sample(4)
# Out:
#      Attrition    Business Travel Department          Education  \
# 812         No  Travel_Frequently        R&D  Bachelor's Degree
# 1065        No      Travel_Rarely      Sales  Associates Degree
# 976         No      Travel_Rarely        R&D  Bachelor's Degree
# 1397        No      Travel_Rarely      Sales  Associates Degree
#
#        Education Field      Emp No  Employee Number  Gender  \
# 812      Life Sciences  STAFF-1126             1126  Female
# 1065         Marketing  STAFF-1986             1986  Female
# 976      Life Sciences  STAFF-1373             1373    Male
# 1397  Technical Degree  STAFF-1541             1541    Male
#
#                     Job Role  Job Satisfaction  ... Relationship Satisfaction  \
# 812   Manufacturing Director                 1  ...                         3
# 1065         Sales Executive                 2  ...                         3
# 976   Manufacturing Director                 2  ...                         1
# ...

# %%
len(df)
# Out:
# 1470

# %%
df.columns
# Out:
# Index(['Attrition', 'Business Travel', 'Department', 'Education',
#        'Education Field', 'Emp No', 'Employee Number', 'Gender', 'Job Role',
#        'Job Satisfaction', 'Marital Status', 'Over Time', 'Over18', 'Age',
#        'Distance From Home', 'Employee Count', 'Environment Satisfaction',
#        'Hourly Rate', 'Job Involvement', 'Job Level', 'Monthly Income',
#        'Monthly Rate', 'Num Companies Worked', 'Percent Salary Hike',
#        'Performance Rating', 'Relationship Satisfaction', 'Standard Hours',
#        'Stock Option Level', 'Total Working Years', 'Training Times Last Year',
#        'Work Life Balance', 'Years At Company', 'Years In Current Role',
#        'Years Since Last Promotion', 'Years With Curr Manager'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Attrition',
#  'Business Travel',
#  'Department',
#  'Education',
#  'Education Field',
#  'Emp No',
#  'Employee Number',
#  'Gender',
#  'Job Role',
#  'Job Satisfaction',
#  'Marital Status',
#  'Over Time',
#  'Over18',
#  'Age',
#  'Distance From Home',
#  'Employee Count',
#  'Environment Satisfaction',
#  'Hourly Rate',
#  'Job Involvement',
#  'Job Level',
#  'Monthly Income',
#  'Monthly Rate',
#  'Num Companies Worked',
#  'Percent Salary Hike',
#  'Performance Rating',
#  'Relationship Satisfaction',
#  'Standard Hours',
#  'Stock Option Level',
#  'Total Working Years',
#  'Training Times Last Year',
#  'Work Life Balance',
#  'Years At Company',
#  'Years In Current Role',
#  'Years Since Last Promotion',
#  'Years With Curr Manager']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df['Department']
# Out:
# 0       Sales
# 1         R&D
# 2         R&D
# 3         R&D
# 4         R&D
#         ...
# 1465      R&D
# 1466      R&D
# 1467    Sales
# 1468    Sales
# 1469      R&D
# Name: Department, Length: 1470, dtype: object

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'R&D', 'HR'], dtype=object)

# %%
df['Department'].nunique()
# Out:
# 3

# %%
df['Department'].value_counts()
# Out:
# R&D      961
# Sales    446
# HR        63
# Name: Department, dtype: int64

# %%
df.dtypes
# Out:
# Attrition                     object
# Business Travel               object
# Department                    object
# Education                     object
# Education Field               object
# Emp No                        object
# Employee Number                int64
# Gender                        object
# Job Role                      object
# Job Satisfaction               int64
# Marital Status                object
# Over Time                     object
# Over18                        object
# Age                            int64
# Distance From Home             int64
# Employee Count                 int64
# Environment Satisfaction       int64
# Hourly Rate                    int64
# Job Involvement                int64
# Job Level                      int64
# Monthly Income                 int64
# Monthly Rate                   int64
# Num Companies Worked           int64
# Percent Salary Hike            int64
# Performance Rating             int64
# ...

# %%
df1=df[['Department','Gender']]

# %%
df1
# Out:
#      Department  Gender
# 0         Sales  Female
# 1           R&D    Male
# 2           R&D    Male
# 3           R&D  Female
# 4           R&D    Male
# ...         ...     ...
# 1465        R&D    Male
# 1466        R&D    Male
# 1467      Sales    Male
# 1468      Sales    Male
# 1469        R&D    Male
#
# [1470 rows x 2 columns]

# %%
df1.value_counts()
# Out:
# Department  Gender
# R&D         Male      582
#             Female    379
# Sales       Male      257
#             Female    189
# HR          Male       43
#             Female     20
# dtype: int64

# %%
df1['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Age'].mean()
# Out:
# 36.923809523809524

# %%
df[df['Gender']=='Female']
# Out:
#      Attrition    Business Travel Department          Education  \
# 0          Yes      Travel_Rarely      Sales  Associates Degree
# 3           No  Travel_Frequently        R&D    Master's Degree
# 6           No      Travel_Rarely        R&D  Bachelor's Degree
# 11          No      Travel_Rarely        R&D  Associates Degree
# 15          No      Travel_Rarely        R&D    Master's Degree
# ...        ...                ...        ...                ...
# 1418       Yes      Travel_Rarely        R&D  Associates Degree
# 1419       Yes      Travel_Rarely      Sales  Bachelor's Degree
# 1420       Yes         Non-Travel        R&D  Bachelor's Degree
# 1421       Yes      Travel_Rarely      Sales    Master's Degree
# 1422       Yes      Travel_Rarely      Sales  Bachelor's Degree
#
#      Education Field      Emp No  Employee Number  Gender  \
# 0      Life Sciences     STAFF-1                1  Female
# 3      Life Sciences     STAFF-5                5  Female
# ...

# %%
df[df['Gender']=='Female'].Age
# Out:
# 0       41
# 3       33
# 6       59
# 11      29
# 15      29
#         ..
# 1418    46
# 1419    46
# 1420    39
# 1421    34
# 1422    33
# Name: Age, Length: 588, dtype: int64

# %%
df[df['Gender']=='Female'].Age.mean()
# Out:
# 37.32993197278912

# %%
df2=df[['Department','Gender']]

# %%
df2
# Out:
#      Department  Gender
# 0         Sales  Female
# 1           R&D    Male
# 2           R&D    Male
# 3           R&D  Female
# 4           R&D    Male
# ...         ...     ...
# 1465        R&D    Male
# 1466        R&D    Male
# 1467      Sales    Male
# 1468      Sales    Male
# 1469        R&D    Male
#
# [1470 rows x 2 columns]

# %%
df2.groupby(['Department','Gender']).size()
# Out:
# Department  Gender
# HR          Female     20
#             Male       43
# R&D         Female    379
#             Male      582
# Sales       Female    189
#             Male      257
# dtype: int64

# %%
df2.groupby(['Department','Gender']).size().plot()
# Out:
# <AxesSubplot:xlabel='Department,Gender'>

# %%
df.sort_values(by='Age')
# Out:
#      Attrition    Business Travel Department          Education  \
# 1006        No         Non-Travel        R&D  Bachelor's Degree
# 828        Yes         Non-Travel        R&D        High School
# 1413       Yes  Travel_Frequently      Sales  Associates Degree
# 296        Yes      Travel_Rarely        R&D  Bachelor's Degree
# 301         No      Travel_Rarely      Sales  Bachelor's Degree
# ...        ...                ...        ...                ...
# 411         No      Travel_Rarely        R&D  Bachelor's Degree
# 536         No      Travel_Rarely      Sales    Master's Degree
# 879         No      Travel_Rarely      Sales    Master's Degree
# 427         No  Travel_Frequently      Sales  Bachelor's Degree
# 1377        No      Travel_Rarely        R&D    Master's Degree
#
#      Education Field      Emp No  Employee Number  Gender  \
# 1006         Medical  STAFF-1839             1839  Female
# 828          Medical  STAFF-1156             1156    Male
# ...

# %%
df.sort_values(by='Job Satisfaction',ascending=False)
# Out:
#      Attrition    Business Travel Department          Education  \
# 0          Yes      Travel_Rarely      Sales  Associates Degree
# 424         No      Travel_Rarely      Sales  Bachelor's Degree
# 413         No  Travel_Frequently        R&D    Master's Degree
# 996         No      Travel_Rarely      Sales  Bachelor's Degree
# 416         No  Travel_Frequently        R&D  Associates Degree
# ...        ...                ...        ...                ...
# 999         No      Travel_Rarely         HR  Bachelor's Degree
# 1262        No      Travel_Rarely        R&D  Bachelor's Degree
# 530         No      Travel_Rarely        R&D  Associates Degree
# 1260        No      Travel_Rarely        R&D        High School
# 861         No      Travel_Rarely      Sales  Bachelor's Degree
#
#        Education Field      Emp No  Employee Number  Gender  \
# 0        Life Sciences     STAFF-1                1  Female
# 424          Marketing   STAFF-568              568    Male
# ...

# %%
df.isnull()
# Out:
#       Attrition  Business Travel  Department  Education  Education Field  \
# 0         False            False       False      False            False
# 1         False            False       False      False            False
# 2         False            False       False      False            False
# 3         False            False       False      False            False
# 4         False            False       False      False            False
# ...         ...              ...         ...        ...              ...
# 1465      False            False       False      False            False
# 1466      False            False       False      False            False
# 1467      False            False       False      False            False
# 1468      False            False       False      False            False
# 1469      False            False       False      False            False
#
#       Emp No  Employee Number  Gender  Job Role  Job Satisfaction  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# Department                    0
# Education                     0
# Education Field               0
# Emp No                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Job Satisfaction              0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Age                           0
# Distance From Home            0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# Performance Rating            0
# Relationship Satisfaction     0
# Standard Hours                0
# Stock Option Level            0
# Total Working Years           0
# ...

# %%
df_left=df[['Gender','Age']]

# %%
df_left
# Out:
#       Gender  Age
# 0     Female   41
# 1       Male   49
# 2       Male   37
# 3     Female   33
# 4       Male   27
# ...      ...  ...
# 1465    Male   34
# 1466    Male   29
# 1467    Male   35
# 1468    Male   23
# 1469    Male   22
#
# [1470 rows x 2 columns]

# %%
df_right=df[['Employee Number','Age']]

# %%
df_right
# Out:
#       Employee Number  Age
# 0                   1   41
# 1                   2   49
# 2                   4   37
# 3                   5   33
# 4                   7   27
# ...               ...  ...
# 1465             1905   34
# 1466             1868   29
# 1467             1667   35
# 1468             1702   23
# 1469             1878   22
#
# [1470 rows x 2 columns]

# %%
df_all=df_left.merge(df_right)

# %%
df_all
# Out:
#        Gender  Age  Employee Number
# 0      Female   41                1
# 1      Female   41               58
# 2      Female   41              176
# 3      Female   41              199
# 4      Female   41              200
# ...       ...  ...              ...
# 69483    Male   60              549
# 69484    Male   60              573
# 69485    Male   60              732
# 69486    Male   60             1233
# 69487    Male   60             1697
#
# [69488 rows x 3 columns]

# %%
df_all1=df_left.merge(df_right,how='inner')

# %%
df_all1
# Out:
#        Gender  Age  Employee Number
# 0      Female   41                1
# 1      Female   41               58
# 2      Female   41              176
# 3      Female   41              199
# 4      Female   41              200
# ...       ...  ...              ...
# 69483    Male   60              549
# 69484    Male   60              573
# 69485    Male   60              732
# 69486    Male   60             1233
# 69487    Male   60             1697
#
# [69488 rows x 3 columns]

# %%
df_all2=df_left.merge(df_right,how='outer')

# %%
df_all2
# Out:
#        Gender  Age  Employee Number
# 0      Female   41                1
# 1      Female   41               58
# 2      Female   41              176
# 3      Female   41              199
# 4      Female   41              200
# ...       ...  ...              ...
# 69483    Male   60              549
# 69484    Male   60              573
# 69485    Male   60              732
# 69486    Male   60             1233
# 69487    Male   60             1697
#
# [69488 rows x 3 columns]

# %%
df_all3=df_left.merge(df_right,how='left')

# %%
df_all3
# Out:
#        Gender  Age  Employee Number
# 0      Female   41                1
# 1      Female   41               58
# 2      Female   41              176
# 3      Female   41              199
# 4      Female   41              200
# ...       ...  ...              ...
# 69483    Male   22             1203
# 69484    Male   22             1605
# 69485    Male   22             2007
# 69486    Male   22             1783
# 69487    Male   22             1878
#
# [69488 rows x 3 columns]

# %%
df_all4=df_left.merge(df_right,how='right')

# %%
df_all4
# Out:
#        Gender  Age  Employee Number
# 0      Female   41                1
# 1      Female   41                1
# 2        Male   41                1
# 3        Male   41                1
# 4        Male   41                1
# ...       ...  ...              ...
# 69483    Male   22             1878
# 69484  Female   22             1878
# 69485    Male   22             1878
# 69486  Female   22             1878
# 69487    Male   22             1878
#
# [69488 rows x 3 columns]

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df1.reset_index()
# Out:
#       index Department  Gender
# 0         0      Sales  Female
# 1         1        R&D    Male
# 2         2        R&D    Male
# 3         3        R&D  Female
# 4         4        R&D    Male
# ...     ...        ...     ...
# 1465   1465        R&D    Male
# 1466   1466        R&D    Male
# 1467   1467      Sales    Male
# 1468   1468      Sales    Male
# 1469   1469        R&D    Male
#
# [1470 rows x 3 columns]

# %%
df1.reset_index(inplace=True,drop=True)

# %%
df1
# Out:
#      Department  Gender
# 0         Sales  Female
# 1           R&D    Male
# 2           R&D    Male
# 3           R&D  Female
# 4           R&D    Male
# ...         ...     ...
# 1465        R&D    Male
# 1466        R&D    Male
# 1467      Sales    Male
# 1468      Sales    Male
# 1469        R&D    Male
#
# [1470 rows x 2 columns]

# %%
df_a_b=pd.concat([df_left,df_right])

# %%
df_a_b
# Out:
#       Gender  Age  Employee Number
# 0     Female   41              NaN
# 1       Male   49              NaN
# 2       Male   37              NaN
# 3     Female   33              NaN
# 4       Male   27              NaN
# ...      ...  ...              ...
# 1465     NaN   34           1905.0
# 1466     NaN   29           1868.0
# 1467     NaN   35           1667.0
# 1468     NaN   23           1702.0
# 1469     NaN   22           1878.0
#
# [2940 rows x 3 columns]

# %%
df_a_b1=df_left.append(df_right)
# Out:
# C:\Users\ashok\AppData\Local\Temp\ipykernel_13412\3991045067.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_a_b1=df_left.append(df_right)

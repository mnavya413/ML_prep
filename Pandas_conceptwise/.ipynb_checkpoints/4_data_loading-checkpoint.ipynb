# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.size
# Out:
# 1000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.sample(4)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 127         128    Male   40                  71                      95
# 33           34    Male   18                  33                      92
# 22           23  Female   46                  25                       5
# 35           36  Female   21                  33                      81

# %%
df.columns.tolist()
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
x=df.columns

# %%
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
len(df)
# Out:
# 200

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Gender, Length: 200, dtype: object

# %%
df1=df[['Gender','Age']]

# %%
df1
# Out:
#      Gender  Age
# 0      Male   19
# 1      Male   21
# 2    Female   20
# 3    Female   23
# 4    Female   31
# ..      ...  ...
# 195  Female   35
# 196  Female   45
# 197    Male   32
# 198    Male   32
# 199    Male   30
#
# [200 rows x 2 columns]

# %%
df1.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.value_counts()
# Out:
# Gender  Age
# Female  31     7
# Male    19     6
# Female  49     6
#         35     6
#         32     6
#               ..
#         43     1
#         42     1
#         37     1
#         67     1
#         18     1
# Length: 87, dtype: int64

# %%
df1['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Gender']=='Male']
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   Male   19                  15                      39
# 1             2   Male   21                  15                      81
# 8             9   Male   64                  19                       3
# 10           11   Male   67                  19                      14
# 14           15   Male   37                  20                      13
# ..          ...    ...  ...                 ...                     ...
# 187         188   Male   28                 101                      68
# 192         193   Male   33                 113                       8
# 197         198   Male   32                 126                      74
# 198         199   Male   32                 137                      18
# 199         200   Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
df[df['Gender']=='Male'].Age
# Out:
# 0      19
# 1      21
# 8      64
# 10     67
# 14     37
#        ..
# 187    28
# 192    33
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 88, dtype: int64

# %%
df[df['Gender']=='Male'].Age.mean()
# Out:
# 39.80681818181818

# %%
filtered_df = df[df['Gender'] == 'Male']
max_spending_score = filtered_df['Spending Score (1-100)'].max()

#df[df['Gender']=='Female']..max()

# %%
max_spending_score
# Out:
# 97

# %%
filtered_df = df[df['Gender'] == 'Female']
max_Annual_income = filtered_df['Annual Income (k$)'].value_counts()

# %%
max_Annual_income
# Out:
# 78     7
# 54     5
# 60     4
# 103    4
# 40     4
# 65     4
# 67     3
# 62     3
# 39     3
# 48     3
# 72     2
# 50     2
# 73     2
# 76     2
# 63     2
# 79     2
# 88     2
# 97     2
# 17     2
# 58     2
# 57     2
# 120    2
# 70     2
# 16     2
# 28     2
# 37     2
# 47     2
# 29     2
# 33     2
# 20     2
# 34     2
# 43     2
# 19     2
# 18     2
# 99     1
# 98     1
# 101    1
# 23     1
# 21     1
# 113    1
# 87     1
# 86     1
# 85     1
# 81     1
# 49     1
# 25     1
# 77     1
# 75     1
# 74     1
# 30     1
# 69     1
# 64     1
# 38     1
# 42     1
# 59     1
# 44     1
# 46     1
# 126    1
# Name: Annual Income (k$), dtype: int64

# %%
max_Annual_income.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.groupby(['Gender','Age']).size()
# Out:
# Gender  Age
# Female  18     1
#         19     2
#         20     2
#         21     4
#         22     2
#               ..
# Male    66     1
#         67     3
#         68     1
#         69     1
#         70     2
# Length: 87, dtype: int64

# %%
df1.groupby(['Gender','Age']).size().plot()
# Out:
# <AxesSubplot:xlabel='Gender,Age'>

# %%
df.sort_values(by='Age')
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 114         115  Female   18                  65                      48
# 91           92    Male   18                  59                      41
# 65           66    Male   18                  48                      59
# 33           34    Male   18                  33                      92
# 0             1    Male   19                  15                      39
# ..          ...     ...  ...                 ...                     ...
# 90           91  Female   68                  59                      55
# 108         109    Male   68                  63                      43
# 57           58    Male   69                  44                      46
# 70           71    Male   70                  49                      55
# 60           61    Male   70                  46                      56
#
# [200 rows x 5 columns]

# %%
df.sort_values(by='CustomerID')
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.sort_values(by='CustomerID',ascending=False)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 199         200    Male   30                 137                      83
# 198         199    Male   32                 137                      18
# 197         198    Male   32                 126                      74
# 196         197  Female   45                 126                      28
# 195         196  Female   35                 120                      79
# ..          ...     ...  ...                 ...                     ...
# 4             5  Female   31                  17                      40
# 3             4  Female   23                  16                      77
# 2             3  Female   20                  16                       6
# 1             2    Male   21                  15                      81
# 0             1    Male   19                  15                      39
#
# [200 rows x 5 columns]

# %%
df.isnull()
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                   False
# 1         False   False  False               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False               False                   False
# 4         False   False  False               False                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df_left=df[['Gender','Age']]

# %%
df_left
# Out:
#      Gender  Age
# 0      Male   19
# 1      Male   21
# 2    Female   20
# 3    Female   23
# 4    Female   31
# ..      ...  ...
# 195  Female   35
# 196  Female   45
# 197    Male   32
# 198    Male   32
# 199    Male   30
#
# [200 rows x 2 columns]

# %%
df_right=df[['CustomerID','Age']]

# %%
df_right
# Out:
#      CustomerID  Age
# 0             1   19
# 1             2   21
# 2             3   20
# 3             4   23
# 4             5   31
# ..          ...  ...
# 195         196   35
# 196         197   45
# 197         198   32
# 198         199   32
# 199         200   30
#
# [200 rows x 2 columns]

# %%
df_all=df_left.merge(df_right)

# %%
df_all
# Out:
#       Gender  Age  CustomerID
# 0       Male   19           1
# 1       Male   19          62
# 2       Male   19          69
# 3       Male   19         112
# 4       Male   19         114
# ...      ...  ...         ...
# 1031  Female   56         161
# 1032  Female   41         185
# 1033  Female   41         189
# 1034  Female   41         185
# 1035  Female   41         189
#
# [1036 rows x 3 columns]

# %%
df_all1=df_left.merge(df_right,how='inner')

# %%
df_all1
# Out:
#       Gender  Age  CustomerID
# 0       Male   19           1
# 1       Male   19          62
# 2       Male   19          69
# 3       Male   19         112
# 4       Male   19         114
# ...      ...  ...         ...
# 1031  Female   56         161
# 1032  Female   41         185
# 1033  Female   41         189
# 1034  Female   41         185
# 1035  Female   41         189
#
# [1036 rows x 3 columns]

# %%
df_all2=df_left.merge(df_right,how='outer')

# %%
df_all2
# Out:
#       Gender  Age  CustomerID
# 0       Male   19           1
# 1       Male   19          62
# 2       Male   19          69
# 3       Male   19         112
# 4       Male   19         114
# ...      ...  ...         ...
# 1031  Female   56         161
# 1032  Female   41         185
# 1033  Female   41         189
# 1034  Female   41         185
# 1035  Female   41         189
#
# [1036 rows x 3 columns]

# %%
df_all3=df_left.merge(df_right,how='left')

# %%
df_all3
# Out:
#      Gender  Age  CustomerID
# 0      Male   19           1
# 1      Male   19          62
# 2      Male   19          69
# 3      Male   19         112
# 4      Male   19         114
# ...     ...  ...         ...
# 1031   Male   30         158
# 1032   Male   30         160
# 1033   Male   30         176
# 1034   Male   30         186
# 1035   Male   30         200
#
# [1036 rows x 3 columns]

# %%
df_all4=df_left.merge(df_right,how='right')

# %%
df_all4
# Out:
#       Gender  Age  CustomerID
# 0       Male   19           1
# 1       Male   19           1
# 2       Male   19           1
# 3     Female   19           1
# 4       Male   19           1
# ...      ...  ...         ...
# 1031  Female   30         200
# 1032  Female   30         200
# 1033  Female   30         200
# 1034    Male   30         200
# 1035    Male   30         200
#
# [1036 rows x 3 columns]

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df1.reset_index()
# Out:
#      index  Gender  Age
# 0        0    Male   19
# 1        1    Male   21
# 2        2  Female   20
# 3        3  Female   23
# 4        4  Female   31
# ..     ...     ...  ...
# 195    195  Female   35
# 196    196  Female   45
# 197    197    Male   32
# 198    198    Male   32
# 199    199    Male   30
#
# [200 rows x 3 columns]

# %%
df1.reset_index(inplace=True,drop=True)

# %%
df1
# Out:
#      Gender  Age
# 0      Male   19
# 1      Male   21
# 2    Female   20
# 3    Female   23
# 4    Female   31
# ..      ...  ...
# 195  Female   35
# 196  Female   45
# 197    Male   32
# 198    Male   32
# 199    Male   30
#
# [200 rows x 2 columns]

# %%
df_a_b=pd.concat([df_left,df_right])

# %%
df_a_b
# Out:
#      Gender  Age  CustomerID
# 0      Male   19         NaN
# 1      Male   21         NaN
# 2    Female   20         NaN
# 3    Female   23         NaN
# 4    Female   31         NaN
# ..      ...  ...         ...
# 195     NaN   35       196.0
# 196     NaN   45       197.0
# 197     NaN   32       198.0
# 198     NaN   32       199.0
# 199     NaN   30       200.0
#
# [400 rows x 3 columns]

# %%
df_a_b1=df_left.append(df_right)
# Out:
# C:\Users\ashok\AppData\Local\Temp\ipykernel_25472\3991045067.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_a_b1=df_left.append(df_right)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(6)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 724          725         1       1              Chambers, Mr. Norman Campbell
# 352          353         0       3                         Elias, Mr. Tannous
# 140          141         0       3              Boulos, Mrs. Joseph (Sultana)
# 33            34         0       2                      Wheadon, Mr. Edward H
# 194          195         1       1  Brown, Mrs. James Joseph (Margaret Tobin)
# 44            45         1       3              Devaney, Miss. Margaret Delia
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 724    male  27.0      1      0      113806  53.1000    E8        S
# 352    male  15.0      1      1        2695   7.2292   NaN        C
# 140  female   NaN      0      2        2678  15.2458   NaN        C
# 33     male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 194  female  44.0      0      0    PC 17610  27.7208    B4        C
# ...

# %%
len(df)
# Out:
# 891

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
x=df.columns

# %%
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 891

# %%
df2=df[['Survived','Sex']]

# %%
df2
# Out:
#      Survived     Sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.value_counts()
# Out:
# Survived  Sex
# 0         male      468
# 1         female    233
#           male      109
# 0         female     81
# dtype: int64

# %%
df2['Sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2['Survived'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dict(df.dtypes)
# Out:
# {'PassengerId': dtype('int64'),
#  'Survived': dtype('int64'),
#  'Pclass': dtype('int64'),
#  'Name': dtype('O'),
#  'Sex': dtype('O'),
#  'Age': dtype('float64'),
#  'SibSp': dtype('int64'),
#  'Parch': dtype('int64'),
#  'Ticket': dtype('O'),
#  'Fare': dtype('float64'),
#  'Cabin': dtype('O'),
#  'Embarked': dtype('O')}

# %%
df[df['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex']=='female'].Age
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# 888     NaN
# Name: Age, Length: 314, dtype: float64

# %%
df[df['Sex']=='female'].Age.mean()
# Out:
# 27.915708812260537

# %%
df[df['Sex']=='male'].Fare.max()
# Out:
# 512.3292

# %%
df[df['Sex']=='female'].Embarked.value_counts()
# Out:
# S    203
# C     73
# Q     36
# Name: Embarked, dtype: int64

# %%
df[df['Sex']=='female'].Embarked.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Sex']=='male'].Pclass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3=df[['Survived','Sex']]

# %%
df3
# Out:
#      Survived     Sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
df3.groupby(['Sex','Survived']).size()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64

# %%
df3.groupby(['Sex','Survived']).size().plot()
# Out:
# <AxesSubplot:xlabel='Sex,Survived'>

# %%
x_group=df3.groupby(['Sex','Survived']).size().reset_index(name='counts')

# %%
sns.barplot(x='Sex',y='counts',data='x_group')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [98], line 1
# ----> 1 sns.barplot(x='Sex',y='counts',data='x_group')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3169 @_deprecate_positional_args
# ...

# %%
pd.DataFrame(x_group)
# Out:
#       Sex  Survived  counts
# 0  female         0      81
# 1  female         1     233
# 2    male         0     468
# 3    male         1     109

# %%
a=pd.DataFrame(x_group)

# %%
a
# Out:
#       Sex  Survived  counts
# 0  female         0      81
# 1  female         1     233
# 2    male         0     468
# 3    male         1     109

# %%
sns.barplot(a['Sex'],a['Survived'],hue='counts')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [108], line 1
# ----> 1 sns.barplot(a['Sex'],a['Survived'],hue='counts')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3169 @_deprecate_positional_args
# ...

# %%
sns.barplot(pd.DataFrame(x_group))
# Out:
# C:\Users\ashok\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [101], line 1
# ----> 1 sns.barplot(pd.DataFrame(x_group))
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].unique().tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [115], line 1
# ----> 1 df['Age'].int().unique().tolist()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'int'

# %%
df.sort_values(by='Ticket')
# Out:
#      PassengerId  Survived  Pclass  \
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
# ..           ...       ...     ...
# 235          236         0       3
# 92            93         0       1
# 219          220         0       2
# 540          541         1       1
# 745          746         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by='Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Embarked'].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df['Embarked'].dropna()
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 889, dtype: object

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df['Embarked'].dropna(inplace=True)

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df.dropna(subset=['Embarked']),df.dropna(subset=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df.dropna(subset=['Embarked'],inplace=True)

# %%
df=df.dropna(subset=['Embarked'])

# %%
df['Embarked'].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age']=df['Age'].fillna(method='bfill')

# %%
df['Age'].mean()
# Out:
# 29.87056116722783

# %%
df['Age']=df['Age'].fillna(method='ffill')

# %%
df['Age'].mean()
# Out:
# 29.581560044893376

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
highest_value=df['Cabin'].value_counts().idxmax()

# %%
highest_value
# Out:
# 'B96 B98'

# %%
df['Cabin'].fillna(highest_value)
# Out:
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Cabin'].fillna(highest_value,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
highest_value1=df['Embarked'].value_counts().idxmax()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
df_temp=df[['Age','Survived','Ticket']]

# %%
df_temp
# Out:
#       Age  Survived            Ticket
# 0    22.0         0         A/5 21171
# 1    38.0         1          PC 17599
# 2    26.0         1  STON/O2. 3101282
# 3    35.0         1            113803
# 4    35.0         0            373450
# ..    ...       ...               ...
# 886  27.0         0            211536
# 887  19.0         1            112053
# 888   NaN         0        W./C. 6607
# 889  26.0         1            111369
# 890  32.0         0            370376
#
# [891 rows x 3 columns]

# %%
df_temp.to_csv('df_temp.csv',index=None)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_gender=df[['Sex','Age']]

# %%
df_gender.groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df_left=df[['Name','Sex']]

# %%
df_right=df[['Name','Age']]

# %%
df_left
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
df_right
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df_all=df_left.merge(df_right)

# %%
df_all
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df_a=pd.DataFrame({'a':[10,20,30],'b':[40,50,60]})

# %%
df_a
# Out:
#     a   b
# 0  10  40
# 1  20  50
# 2  30  60

# %%
df_b=pd.DataFrame({'a':[100,200,300],'b':[400,500,600]})

# %%
df_b
# Out:
#      a    b
# 0  100  400
# 1  200  500
# 2  300  600

# %%
df_a_b=pd.concat([df_a,df_b])

# %%
df_a_b
# Out:
#      a    b
# 0   10   40
# 1   20   50
# 2   30   60
# 0  100  400
# 1  200  500
# 2  300  600

# %%
df_a
# Out:
#     a   b
# 0  10  40
# 1  20  50
# 2  30  60

# %%
df_b
# Out:
#      a    b
# 0  100  400
# 1  200  500
# 2  300  600

# %%
df_c=pd.DataFrame({'b':[100,500,400],'c':[400,500,600]})

# %%
df_c
# Out:
#      b    c
# 0  100  400
# 1  500  500
# 2  400  600

# %%
df_all1=df_b.merge(df_c)

# %%
df_all1
# Out:
#      a    b    c
# 0  100  400  600
# 1  200  500  500

# %%
df_all1=df_b.merge(df_c,how='inner')

# %%
df_all1
# Out:
#      a    b    c
# 0  100  400  600
# 1  200  500  500

# %%
df_all1=df_b.merge(df_c,how='outer')

# %%
df_all1
# Out:
#        a    b      c
# 0  100.0  400  600.0
# 1  200.0  500  500.0
# 2  300.0  600    NaN
# 3    NaN  100  400.0

# %%
df_all1=df_b.merge(df_c,how='left')

# %%
df_all1
# Out:
#      a    b      c
# 0  100  400  600.0
# 1  200  500  500.0
# 2  300  600    NaN

# %%
df_b
# Out:
#      a    b
# 0  100  400
# 1  200  500
# 2  300  600

# %%
df_c
# Out:
#      b    c
# 0  100  400
# 1  500  500
# 2  400  600

# %%
df_all1=df_b.merge(df_c,how='right')

# %%
df_all1
# Out:
#        a    b    c
# 0    NaN  100  400
# 1  200.0  500  500
# 2  100.0  400  600

# %%
#index
df_temp
# Out:
#       Age  Survived            Ticket
# 0    22.0         0         A/5 21171
# 1    38.0         1          PC 17599
# 2    26.0         1  STON/O2. 3101282
# 3    35.0         1            113803
# 4    35.0         0            373450
# ..    ...       ...               ...
# 886  27.0         0            211536
# 887  19.0         1            112053
# 888   NaN         0        W./C. 6607
# 889  26.0         1            111369
# 890  32.0         0            370376
#
# [891 rows x 3 columns]

# %%
df_10=df_temp.sample(10)

# %%
df_10
# Out:
#       Age  Survived             Ticket
# 314  43.0         0       F.C.C. 13529
# 378  20.0         0               2648
# 778   NaN         0              36865
# 627  21.0         1              13502
# 826   NaN         0               1601
# 636  32.0         0  STON/O 2. 3101292
# 156  16.0         1              35851
# 715  19.0         0             348124
# 545  64.0         0                693
# 380  42.0         1           PC 17757

# %%
df_10.index
# Out:
# Int64Index([314, 378, 778, 627, 826, 636, 156, 715, 545, 380], dtype='int64')

# %%
df_10.reset_index()
# Out:
#    index   Age  Survived             Ticket
# 0    314  43.0         0       F.C.C. 13529
# 1    378  20.0         0               2648
# 2    778   NaN         0              36865
# 3    627  21.0         1              13502
# 4    826   NaN         0               1601
# 5    636  32.0         0  STON/O 2. 3101292
# 6    156  16.0         1              35851
# 7    715  19.0         0             348124
# 8    545  64.0         0                693
# 9    380  42.0         1           PC 17757

# %%
df_10
# Out:
#       Age  Survived             Ticket
# 314  43.0         0       F.C.C. 13529
# 378  20.0         0               2648
# 778   NaN         0              36865
# 627  21.0         1              13502
# 826   NaN         0               1601
# 636  32.0         0  STON/O 2. 3101292
# 156  16.0         1              35851
# 715  19.0         0             348124
# 545  64.0         0                693
# 380  42.0         1           PC 17757

# %%
df_10.reset_index(inplace=True,drop=True)

# %%
df_10
# Out:
#     Age  Survived             Ticket
# 0  43.0         0       F.C.C. 13529
# 1  20.0         0               2648
# 2   NaN         0              36865
# 3  21.0         1              13502
# 4   NaN         0               1601
# 5  32.0         0  STON/O 2. 3101292
# 6  16.0         1              35851
# 7  19.0         0             348124
# 8  64.0         0                693
# 9  42.0         1           PC 17757

# %%
df_10["new_column"]="Apple"

# %%
df_10
# Out:
#     Age  Survived             Ticket new_column
# 0  43.0         0       F.C.C. 13529      Apple
# 1  20.0         0               2648      Apple
# 2   NaN         0              36865      Apple
# 3  21.0         1              13502      Apple
# 4   NaN         0               1601      Apple
# 5  32.0         0  STON/O 2. 3101292      Apple
# 6  16.0         1              35851      Apple
# 7  19.0         0             348124      Apple
# 8  64.0         0                693      Apple
# 9  42.0         1           PC 17757      Apple

# %%
ticket_values=df_10["Ticket"].values.tolist()

# %%
ticket_values
# Out:
# ['F.C.C. 13529',
#  '2648',
#  '36865',
#  '13502',
#  '1601',
#  'STON/O 2. 3101292',
#  '35851',
#  '348124',
#  '693',
#  'PC 17757']

# %%
ticket_values1=[i[-2:] for i in ticket_values]

# %%
ticket_values1
# Out:
# ['29', '48', '65', '02', '01', '92', '51', '24', '93', '57']

# %%
ticket_values2=[int(i) for i in ticket_values1]

# %%
ticket_values2
# Out:
# [29, 48, 65, 2, 1, 92, 51, 24, 93, 57]

# %%
df_10["Price"]=ticket_values2

# %%
df_10
# Out:
#     Age  Survived             Ticket new_column  Price
# 0  43.0         0       F.C.C. 13529      Apple     29
# 1  20.0         0               2648      Apple     48
# 2   NaN         0              36865      Apple     65
# 3  21.0         1              13502      Apple      2
# 4   NaN         0               1601      Apple      1
# 5  32.0         0  STON/O 2. 3101292      Apple     92
# 6  16.0         1              35851      Apple     51
# 7  19.0         0             348124      Apple     24
# 8  64.0         0                693      Apple     93
# 9  42.0         1           PC 17757      Apple     57

# %%
df_10.sort_values(by='Price',inplace=True)

# %%
df_10
# Out:
#     Age  Survived             Ticket new_column  Price
# 4   NaN         0               1601      Apple      1
# 3  21.0         1              13502      Apple      2
# 7  19.0         0             348124      Apple     24
# 0  43.0         0       F.C.C. 13529      Apple     29
# 1  20.0         0               2648      Apple     48
# 6  16.0         1              35851      Apple     51
# 9  42.0         1           PC 17757      Apple     57
# 2   NaN         0              36865      Apple     65
# 5  32.0         0  STON/O 2. 3101292      Apple     92
# 8  64.0         0                693      Apple     93

# %%
a='25'
int(a)
# Out:
# 25

# %%
a_list=['25','35']
[int(i) for i in a_list]
# Out:
# [25, 35]

# %%
x="Apple"

# %%
x[3:]
# Out:
# 'le'

# %%
x[-2:]
# Out:
# 'le'

# %%
y="Target"

# %%
y[4:]
# Out:
# 'et'

# %%
y[-2:]
# Out:
# 'et'

# %%
temp_list=['Apple','Target']

# %%
temp_list1=[i[-2:] for i in temp_list]

# %%
temp_list1
# Out:
# ['le', 'et']
